# %% [markdown]
# # Fashion Dataset EDA
#
# This notebook performs shape, schema, missing value, duplicate, unique count, and distribution analysis.

# %%
from pathlib import Path
import pandas as pd
from app.preprocessing.eda import dataset_summary, save_distribution_plots

path = Path('../data/raw/styles.csv')
if not path.exists():
    path = Path('../data/sample_products.csv')
df = pd.read_csv(path)
dataset_summary(df)

# %%
save_distribution_plots(df, Path('../docs/eda'))
